# %%
# import csv as dataframe
import pandas as pd

df = pd.read_csv("c:/Users/elvir/Documents/Git_Projekte/mlops/mlops_sose25_ei/combined_stock_data - full.csv")

# print the last 8 rows of the dataframe as a complite table just follow columns Date, Close High, Low, Open, Volume and stock with the name AAPL
df = df[df['stock'] == 
        # 'AAPL'
        # 'AMZN'
        # 'GOOGL'
        # 'META'
        # 'MSFT'
        # 'NFLX'
        # 'NVDA'
         'TSLA'
]
# calculate the return of the stock in percentage and write it as percentage in the column 'return'
df['return'] = df['Close'].pct_change() * 100

print(df.tail(2).to_string(index=False, columns=["Date", "Close", "High", "Low", "Open", "Volume", "stock", "return"]))
#print(df.tail(16).to_string(index=False))
#print(df.tail(8))
# Out:
#                      Date      Close       High        Low       Open   Volume stock   return
# 2025-04-07 19:30:00+00:00 233.289993 234.660004 228.170105 229.440002 11034151  TSLA 1.673566
# 2025-04-08 13:30:00+00:00 243.729996 248.860001 242.511993 245.050003 15038950  TSLA 4.475118
